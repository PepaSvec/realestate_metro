# %%
from selenium import webdriver

# %%
import time

# %%
import csv

# %%
from math import ceil

# %%
from bs4 import BeautifulSoup

# %%
import datetime

# %%
import time

# %%
import pandas as pd

# %%
link_base = "https://www.sreality.cz"

# %%
class Downloader_SR():
    def __init__(self, link = 'https://www.sreality.cz/hledani', lease = 'pronajem', typ = 'byty', region = 'praha'):
        self.link = link + '/' + lease+ '/' + typ +'/' + region + '?strana='
        self.n_matches = self.number_pg()
        self.n_pages = ceil(self.n_matches/20)
        self.link_set = [self.link + str(k+1) for k in range(0, self.n_pages)]
        self.link_container = []
        
    def number_pg(self):
        driver = webdriver.Chrome("C:\\chromedriver\\chromedriver.exe")
        driver.get(self.link)
        time.sleep(2)
        res1 = driver.execute_script("return document.documentElement.outerHTML")
        soup = BeautifulSoup(res1, "lxml")
        pg_n = soup.find_all("span", {"class":"numero ng-binding"})
        driver.quit()
        text = pg_n[1].get_text()
        return int(text.replace("\xa0",""))
    
    @staticmethod
    def create_csv():
        dat = datetime.datetime.now()
        with open(f'links{dat.day}.{dat.month}.{dat.year}.csv', 'w') as f:
            writer = csv.writer(f, delimiter = ";", lineterminator = '\n')
            writer.writerow([f"These link were scraped on {dat.day}.{dat.month}.{dat.year} after {dat.hour}:{dat.minute}"])
    
    def find_a(self, limit = 1):
        self.create_csv()
        driver = webdriver.Chrome("C:\\chromedriver\\chromedriver.exe")
        dat = datetime.datetime.now()
        start_time = time.time()
        for page in self.link_set[:limit]:
            driver.get(page)
            time.sleep(2)
            res1 = driver.execute_script("return document.documentElement.outerHTML")
            soup = BeautifulSoup(res1, "lxml")
            links = soup.find_all("a", {"class":"title"})
            for non_sponsored_links in links[1:]:
                self.link_container.append(link_base + non_sponsored_links['href'])
            run_time = time.time() - start_time
            print(f"{len(self.link_container)} links fetched;{round(len(self.link_container)/self.n_matches,3)}% finished;{round(run_time/60,2)} time taken")
            with open(f'links{dat.day}.{dat.month}.{dat.year}.csv', 'a+') as f:
                writer = csv.writer(f, delimiter = ";", lineterminator = '\n')
                for non_sponsored_links in links[1:]:
                    writer.writerow([link_base + non_sponsored_links['href']])
                    
            run_time2 = time.time() - start_time
            print("appended into csv")
            print(f"run time is {round(run_time2/60,2)} minutes")
        driver.quit()
        
    def dataF(self):
        driver = webdriver.Chrome("C:\\chromedriver\\chromedriver.exe")
        box = [Property().data for g in gist]
        self.df = pd.concat([Property(link, webdriver.Chrome("C:\\chromedriver\\chromedriver.exe")).data for link in self.link_container],axis = 0, sort = True)

# %%
# %%time
first = Downloader_SR()
# Out:
# Wall time: 12.1 s

# %%
first.n_matches
# Out:
# 8087

# %%
first.n_pages
# Out:
# 405

# %%
first.link_set[-1]
# Out:
# 'https://www.sreality.cz/hledani/pronajem/byty/praha?strana=405'

# %%
first.find_a(limit = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-f211dab4da72> in <module>
# ----> 1 first.find_a(limit = 1)
#
# <ipython-input-45-d42fd2a852b5> in find_a(self, limit)
#      27     def find_a(self, limit = 1):
#      28         self.create_csv()
# ---> 29         driver = webdriver.Chrome("C:\\chromedriver\\chromedriver.exe")
#      30         dat = datetime.datetime.now()
#      31         start_time = time.time()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~\Anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
first.link_container[0]
# Out:
# 'https://www.sreality.cz/detail/pronajem/byt/2+kk/praha-zizkov-prokopova/563691100'

# %%
len(first.link_container)
# Out:
# 20

# %%
# %%time
first.dataF()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# <ipython-input-45-d42fd2a852b5> in dataF(self)
#      51
#      52     def dataF(self):
# ---> 53         self.df = pd.concat([Property(link, webdriver.Chrome("C:\\chromedriver\\chromedriver.exe")).data for link in self.link_container],axis = 0, sort = True)
#
# <ipython-input-45-d42fd2a852b5> in <listcomp>(.0)
#      51
#      52     def dataF(self):
# ---> 53         self.df = pd.concat([Property(link, webdriver.Chrome("C:\\chromedriver\\chromedriver.exe")).data for link in self.link_container],axis = 0, sort = True)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~\Anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
first.df
# Out:
#                                            Adresa Aktualizace:  \
# 0             Ruská, Praha 10 - Vršovice Panorama       [Dnes]
# 0                    Kozácká, Praha 10 - Vršovice       [Dnes]
# 0             Ocelářská, Praha 9 - Libeň Panorama       [Dnes]
# 0                    Sokolovská, Praha 8 - Karlín       [Dnes]
# 0          Karoliny Světlé, Praha 1 - Staré Město       [Dnes]
# 0                    Blahníkova, Praha 3 - Žižkov       [Dnes]
# 0                    Blahníkova, Praha 3 - Žižkov       [Dnes]
# 0                     Řipská, Praha 3 - Vinohrady       [Dnes]
# 0                  Slavíkova, Praha 2 - Vinohrady       [Dnes]
# 0                      Pod lázní, Praha 4 - Nusle       [Dnes]
# 0                  Slavíkova, Praha 2 - Vinohrady       [Dnes]
# 0                    Blahníkova, Praha 3 - Žižkov       [Dnes]
# 0                    Blahníkova, Praha 3 - Žižkov       [Dnes]
# 0          Karoliny Světlé, Praha 1 - Staré Město       [Dnes]
# 0                    Blahníkova, Praha 3 - Žižkov       [Dnes]
# 0                    Hlaváčkova, Praha 5 - Košíře       [Dnes]
# 0               Petrohradská, Praha 10 - Vršovice       [Dnes]
# 0         U Nikolajky, Praha 5 - Smíchov Panorama       [Dnes]
# 0  Honzíkova, Praha 10 - Dolní Měcholupy Panorama      [Včera]
# 0                 Levá, Praha 4 - Podolí Panorama       [Dnes]
#
#             Balkón:                                          Bankomat:  \
# 0               NaN              [Bankomat České spořitelny,  (280 m)]
# 0               NaN                                                NaN
# 0               NaN                      [Bankomat Air Bank,  (106 m)]
# 0               NaN                          [Bankomat ČSOB,  (176 m)]
# 0               NaN               [Raiffeisenbank - bankomat,  (49 m)]
# 0               NaN                                                NaN
# 0               NaN              [Bankomat České spořitelny,  (195 m)]
# 0               NaN                 [Bankomat Komerční banky,  (55 m)]
# 0               NaN                       [Bankomat Euronet,  (252 m)]
# 0               NaN                [Bankomat Komerční banky,  (471 m)]
# 0               NaN                       [Bankomat Euronet,  (252 m)]
# 0               NaN              [Bankomat České spořitelny,  (195 m)]
# 0               NaN                                                NaN
# 0               NaN               [Raiffeisenbank - bankomat,  (49 m)]
# 0               NaN              [Bankomat České spořitelny,  (195 m)]
# 0               NaN                [Bankomat Komerční banky,  (716 m)]
# 0  ['boolean-true']                                                NaN
# 0               NaN             [Bankomat MONETA Money Bank,  (768 m)]
# 0               NaN  [Bankomat ČSOB - Československá obchodní banka...
# 0               NaN                [Bankomat Komerční banky,  (192 m)]
#
#        Bezbariérový:                       Bus MHD:  \
# 0                NaN          [Slovinská,  (416 m)]
# 0                NaN                            NaN
# 0  ['boolean-false']       [Českomoravská,  (81 m)]
# 0                NaN          [Pernerova,  (389 m)]
# 0                NaN  [Mariánské náměstí,  (604 m)]
# 0                NaN        [U Památníku,  (174 m)]
# 0                NaN        [U Památníku,  (174 m)]
# 0                NaN            [Orionka,  (479 m)]
# 0                NaN        [Na Smetance,  (737 m)]
# 0                NaN            [Jezerka,  (105 m)]
# 0                NaN        [Na Smetance,  (737 m)]
# 0                NaN        [U Památníku,  (174 m)]
# 0                NaN        [U Památníku,  (174 m)]
# 0                NaN  [Mariánské náměstí,  (604 m)]
# 0                NaN        [U Památníku,  (174 m)]
# 0  ['boolean-false']           [Klamovka,  (107 m)]
# 0  ['boolean-false']                            NaN
# 0   ['boolean-true']            [Václavka,  (94 m)]
# 0   ['boolean-true']        [Kutnohorská,  (315 m)]
# 0  ['boolean-false']              [Doliny,  (50 m)]
#
#                                        Celková cena:  \
# 0                               [14 990 Kč za měsíc]
# 0                 [12 000 Kč za měsíc, bez poplatků]
# 0                               [14 000 Kč za měsíc]
# 0                 [10 000 Kč za měsíc, bez poplatků]
# 0                 [23 500 Kč za měsíc, bez poplatků]
# 0                 [12 500 Kč za měsíc, bez poplatků]
# 0                 [14 000 Kč za měsíc, bez poplatků]
# 0                 [13 500 Kč za měsíc, bez poplatků]
# 0                 [18 500 Kč za měsíc, bez poplatků]
# 0                  [9 800 Kč za měsíc, + provize RK]
# 0                               [19 000 Kč za měsíc]
# 0                               [14 000 Kč za měsíc]
# 0                               [15 500 Kč za měsíc]
# 0                               [23 500 Kč za měsíc]
# 0                               [12 500 Kč za měsíc]
# 0                               [15 500 Kč za měsíc]
# 0  [11 000 Kč za měsíc, + provize RK, včetně DPH,...
# 0                 [18 000 Kč za měsíc, bez poplatků]
# 0  [14 000 Kč za měsíc, + provize RK, bez poplatk...
# 0  [12 900 Kč za měsíc, + provize RK, včetně práv...
#
#                                        Cukrárna: Datum nastěhování:  \
# 0  [Ludmila Horníková - Kavárna Maluj,  (407 m)]                NaN
# 0                                            NaN                NaN
# 0                     [Café Coffee Day,  (75 m)]                NaN
# 0                [Dortnaobjednavku.cz,  (247 m)]            [Ihned]
# 0                     [Kavárna Slavia,  (149 m)]            [Ihned]
# 0                                            NaN                NaN
# 0                        [Café Vítkov,  (344 m)]            [Ihned]
# 0         [Pekařství a cukrárna Benea,  (141 m)]            [Ihned]
# 0                   [Vinohradské dorty,  (64 m)]            [Ihned]
# 0                   [Cukrárna Charlie,  (457 m)]                NaN
# 0                   [Vinohradské dorty,  (64 m)]                NaN
# 0                        [Café Vítkov,  (344 m)]                NaN
# 0                                            NaN                NaN
# 0                     [Kavárna Slavia,  (149 m)]                NaN
# 0                        [Café Vítkov,  (344 m)]                NaN
# 0        [Cukrárna Snídejte šampaňské,  (997 m)]                NaN
# 0                                            NaN                NaN
# 0        [Cukrárna Snídejte šampaňské,  (422 m)]                NaN
# 0                       [TRIO MALÝ HÁJ,  (35 m)]       [01.05.2020]
# 0                            [Cheecup,  (146 m)]            [Ihned]
#
#                                           Divadlo:  ... Užitná plocha:  \
# 0  [Divadelní společnost Josefa Dvořáka,  (466 m)]  ...         2]
# 0                                              NaN  ...         2]
# 0                         [Divadlo Gong,  (276 m)]  ...         2]
# 0           [Divadlo (bez záruky) Praha,  (309 m)]  ...         2]
# 0                         [Divadlo Viola,  (51 m)]  ...        2]
# 0                                              NaN  ...         2]
# 0       [Žižkovské divadlo Járy Cimrmana,  (88 m)]  ...         2]
# 0  [Divadelní společnost Josefa Dvořáka,  (708 m)]  ...         2]
# 0                        [Theatre ROYAL,  (505 m)]  ...         2]
# 0                   [Divadlo Na Jezerce,  (104 m)]  ...         2]
# 0                        [Theatre ROYAL,  (505 m)]  ...         2]
# 0       [Žižkovské divadlo Járy Cimrmana,  (88 m)]  ...         2]
# 0                                              NaN  ...         2]
# 0                         [Divadlo Viola,  (51 m)]  ...         2]
# 0       [Žižkovské divadlo Járy Cimrmana,  (88 m)]  ...         2]
# 0                    [JUDr. Jiří Šilhán,  (507 m)]  ...         2]
# 0                                              NaN  ...         2]
# 0                       [Divadlo Orfeus,  (729 m)]  ...         2]
# 0           [Loutkové divadlo Frydolín,  (1793 m)]  ...         2]
# 0                    [Staré purkrabství,  (772 m)]  ...         2]
#
#                                           Veterinář:  \
# 0                  [MVDr. Alexandr Skácel,  (293 m)]
# 0                                                NaN
# 0  [ERIKA veterinární klinika - MVDr. Pavel Hron,...
# 0                       [MVDr. Jan Dubský,  (876 m)]
# 0          [MVDr. Katka Sviták Novozámská,  (348 m)]
# 0                                                NaN
# 0                       [MVDr. Jan Dubský,  (408 m)]
# 0                  [MVDr. Alexandr Skácel,  (227 m)]
# 0              [Veterinární klinika Panda,  (202 m)]
# 0    [Veterinární ošetřovna Nusle, s.r.o.,  (372 m)]
# 0              [Veterinární klinika Panda,  (202 m)]
# 0                       [MVDr. Jan Dubský,  (408 m)]
# 0                                                NaN
# 0          [MVDr. Katka Sviták Novozámská,  (348 m)]
# 0                       [MVDr. Jan Dubský,  (408 m)]
# 0  [Veterinární klinika - MVDr. Pavel Santar, MVD...
# 0                                                NaN
# 0                    [MVDr. Jana Lukešová,  (535 m)]
# 0            [Veterinární ordinace MiaVet,  (877 m)]
# 0                   [MVDr. Lucie Boháčová,  (132 m)]
#
#                                    Večerka:  \
# 0                         [BILLA,  (469 m)]
# 0                                       NaN
# 0                  [Tesco Expres,  (291 m)]
# 0  [Smíšené zboží Sokolovská 128,  (298 m)]
# 0             [MANNI MINI MARKET,  (510 m)]
# 0                                       NaN
# 0                [Shalamar Foods,  (390 m)]
# 0            [Albert Supermarket,  (145 m)]
# 0          [Potraviny Kubelíkova,  (350 m)]
# 0                  [Tesco Expres,  (434 m)]
# 0          [Potraviny Kubelíkova,  (350 m)]
# 0                [Shalamar Foods,  (390 m)]
# 0                                       NaN
# 0             [MANNI MINI MARKET,  (510 m)]
# 0                [Shalamar Foods,  (390 m)]
# 0        [Potraviny Plzeňská 127,  (130 m)]
# 0                                       NaN
# 0            [Albert Supermarket,  (349 m)]
# 0                       [Iceland,  (303 m)]
# 0               [FEBAJ maloobchod,  (54 m)]
#
#                                      Vlak:  Vlastnictví:              Voda:  \
# 0               [Praha-Vršovice,  (902 m)]  [Družstevní]  [Dálkový vodovod]
# 0                                      NaN      [Osobní]  [Dálkový vodovod]
# 0                  [Praha-Libeň,  (861 m)]      [Osobní]     [Místní zdroj]
# 0         [Praha-Bubny Vltavská,  (872 m)]      [Osobní]  [Dálkový vodovod]
# 0    [Praha Masarykovo nádraží,  (1488 m)]      [Osobní]  [Dálkový vodovod]
# 0         [Praha hlavní nádraží,  (850 m)]      [Osobní]  [Dálkový vodovod]
# 0         [Praha hlavní nádraží,  (850 m)]      [Osobní]  [Dálkový vodovod]
# 0        [Praha hlavní nádraží,  (1301 m)]      [Osobní]  [Dálkový vodovod]
# 0         [Praha hlavní nádraží,  (926 m)]      [Osobní]  [Dálkový vodovod]
# 0               [Praha-Vršovice,  (751 m)]      [Osobní]                NaN
# 0         [Praha hlavní nádraží,  (926 m)]      [Osobní]                NaN
# 0         [Praha hlavní nádraží,  (850 m)]      [Osobní]                NaN
# 0         [Praha hlavní nádraží,  (850 m)]      [Osobní]                NaN
# 0    [Praha Masarykovo nádraží,  (1488 m)]      [Osobní]                NaN
# 0         [Praha hlavní nádraží,  (850 m)]      [Osobní]                NaN
# 0               [Praha-Cibulka,  (1499 m)]      [Osobní]                NaN
# 0                                      NaN      [Osobní]                NaN
# 0  [Praha-Smíchov severní nást.,  (972 m)]      [Osobní]                NaN
# 0              [Praha-Hostivař,  (1714 m)]      [Osobní]  [Dálkový vodovod]
# 0               [Praha-Smíchov,  (1171 m)]  [Družstevní]  [Dálkový vodovod]
#
#           Vybavení:             Výtah:  \
# 0               NaN   ['boolean-true']
# 0  ['boolean-true']  ['boolean-false']
# 0               NaN   ['boolean-true']
# 0  ['boolean-true']  ['boolean-false']
# 0  ['boolean-true']   ['boolean-true']
# 0  ['boolean-true']   ['boolean-true']
# 0  ['boolean-true']   ['boolean-true']
# 0  ['boolean-true']   ['boolean-true']
# 0  ['boolean-true']   ['boolean-true']
# 0               NaN  ['boolean-false']
# 0  ['boolean-true']                NaN
# 0  ['boolean-true']   ['boolean-true']
# 0  ['boolean-true']   ['boolean-true']
# 0  ['boolean-true']   ['boolean-true']
# 0  ['boolean-true']   ['boolean-true']
# 0               NaN   ['boolean-true']
# 0               NaN                NaN
# 0  ['boolean-true']   ['boolean-true']
# 0        [Částečně]   ['boolean-true']
# 0               NaN  ['boolean-false']
#
#                                               Škola:  \
# 0  [Obchodní akademie Praha 10, Heroldovy sady,  ...
# 0                                                NaN
# 0  [Střední škola a vyšší odborná škola umělecká ...
# 0      [Církevní střední škola Jana Boska,  (256 m)]
# 0  [SPSŠ Betlémská - Střední průmyslová škola str...
# 0                                                NaN
# 0                  [ZUŠ, Praha 3, Štítného,  (88 m)]
# 0  [Střední škola knižní kultury Praha, o.p.s.,  ...
# 0   [ZŠ Praha 3, náměstí Jiřího z Poděbrad,  (73 m)]
# 0                  [Základní škola Square,  (382 m)]
# 0   [ZŠ Praha 3, náměstí Jiřího z Poděbrad,  (73 m)]
# 0                  [ZUŠ, Praha 3, Štítného,  (88 m)]
# 0                                                NaN
# 0  [SPSŠ Betlémská - Střední průmyslová škola str...
# 0                  [ZUŠ, Praha 3, Štítného,  (88 m)]
# 0  [Základní škola, Praha 5, Pod Radnicí 5,  (84 m)]
# 0                                                NaN
# 0                      [Obchodní institut,  (347 m)]
# 0              [ZŠ a MŠ Praha 10, U Školy,  (428 m)]
# 0          [ZŠ Praha 4, Nedvědovo náměstí,  (124 m)]
#
#                                              Školka:
# 0  [Kouzelné školy - mateřská škola a základní šk...
# 0                                                NaN
# 0                   [MŠ Praha 9, Kovářská,  (369 m)]
# 0       [ZŠ a MŠ Praha 8, Lyčkovo náměstí,  (870 m)]
# 0                 [MŠ sv. Voršily v Praze,  (157 m)]
# 0                                                NaN
# 0          [Sdružení dětí Veverka, s.r.o.,  (128 m)]
# 0      [Mateřská škola, Praha 3, Perunova,  (155 m)]
# 0                   [Piccole Pesti, s.r.o.,  (98 m)]
# 0              [ZŠ a MŠ Praha 4, Sdružení,  (399 m)]
# 0                   [Piccole Pesti, s.r.o.,  (98 m)]
# 0          [Sdružení dětí Veverka, s.r.o.,  (128 m)]
# 0                                                NaN
# 0                 [MŠ sv. Voršily v Praze,  (157 m)]
# 0          [Sdružení dětí Veverka, s.r.o.,  (128 m)]
# 0  [Montessori školy Andílek - mateřská škola a z...
# 0                                                NaN
# 0           [Montessori pohybová školička,  (383 m)]
# 0               [MŠ Praha 10, Pod Areálem,  (526 m)]
# 0                 [MŠ Praha 4, Voráčovská,  (295 m)]
#
# [20 rows x 56 columns]

# %%
class Property():
    def __init__(self, link, driver):
        self.link = link
        self.driver = driver
        self.items = {}
        soup = self.scrape()
        self.parser(soup)
        self.data = self.cr_data() 
        
        
    def scrape(self):
        self.driver.get(self.link)
        time.sleep(2)
        gist = self.driver.execute_script("return document.documentElement.outerHTML")
        #driver.quit()
        return gist
    
    def parser(self, gist):
        info = BeautifulSoup(gist, "lxml")
        lists = info.find_all("li")
        self.items["Title"] = info.find("span",{"itemprop":"name"}).findChild().get_text().replace("\n","").replace("\xa0"," ")
        self.items["Adresa"] = info.find("span",{"class": "location"}).get_text().replace("\n","").replace("\xa0"," ")
        for k in lists:
            try:
                column = k.find("label").get_text()
            except:
                break
            try:
                value = [k.find("strong").get_text()]
            except:
                try:
                    value = [k.find("a").get_text(), k.find("span", {"class":"c-pois__distance ng-binding"}).get_text()]
                except:
                    value = [k.find("span",{"class":"c-pois__poi-text ng-binding ng-scope"}).get_text(),k.find("span", {"class":"c-pois__distance ng-binding"}).get_text()]

            if value[0] == "\n\n\n\n\n\n\n":
                try:
                    value[0] = k.find("strong").findChild("span",{"class": "icof icon-cross ng-scope"})["ng-if"].split(" ")[-1]
                except:
                    value[0] = k.find("strong").findChild("span",{"class": "icof icon-ok ng-scope"})["ng-if"].split(" ")[-1]

            #we clean the values a little bit
            keys = [val.replace("\n","") for val in value]
            keys_a = [ki.replace("\xa0"," ") for ki in keys]    

            #add it to the dictionary
            self.items[column] = keys_a
            
    def cr_data(self):
        vals = list(self.items.values())
        keys = list(self.items.keys())
        df= pd.DataFrame(zip(vals)).transpose()
        df.columns = keys
        return df

# %%
# %%time
second = Property('https://www.sreality.cz/detail/pronajem/byt/2+1/praha-smichov-nad-budankami-i/2389851740')
# Out:
# Wall time: 12 s

# %%
second.data
# Out:
#                      Title                                       Adresa  \
# 0  Pronájem bytu 2+1 58 m²  Nad Buďánkami I, Praha 5 - Smíchov Panorama
#
#           Celková cena:                                   Poznámka k ceně:  \
# 0  [20 000 Kč za měsíc]  [poplatky 950,- Kč/osoba/měsíc + přepis elektř...
#
#   ID zakázky: Aktualizace:    Stavba:  Stav objektu: Vlastnictví:  \
# 0      [3987]      [Včera]  [Cihlová]  [Velmi dobrý]     [Osobní]
#
#                   Podlaží:  ...                     Lékárna:  \
# 0  [2. podlaží z celkem 4]  ...  [Lékárna Melissa,  (250 m)]
#
#                         Vlak:                      Škola:  \
# 0  [Praha-Cibulka,  (1020 m)]  [ZUŠ Na Popelce,  (221 m)]
#
#                                   Lékař:  \
# 0  [MUDr. Drahomíra Miškovská,  (152 m)]
#
#                                          Školka:                Restaurace:  \
# 0  [Studio Lentilka – soukromá školka,  (198 m)]  [Yang Zi Jiang,  (232 m)]
#
#                                       Obchod:  \
# 0  [Obchodní centrum Nový Smíchov,  (2238 m)]
#
#                       Sportoviště:                  Tram:  \
# 0  [TJ Banka Praha z.s.,  (303 m)]  [Kavalírka,  (196 m)]
#
#                   Metro:
# 0  [Jinonice,  (1910 m)]
#
# [1 rows x 39 columns]
