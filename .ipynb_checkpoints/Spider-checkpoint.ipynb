# %%
from math import ceil

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
from selenium import webdriver

# %%
import re

# %%
class Downloader():
    def __init__(self):
        self.name = "Pepa"

# %% [markdown]
# OOP

# %%
A_person = Downloader()

# %%
A_person.name
# Out:
# 'Pepa'

# %% [markdown]
# Beautiful SOUP

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="{{ html.lang }}" ng-app="sreality" ng-controller="MainCtrl">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/>
#   <!--- Nastaveni meta pres JS a ne pres Angular, aby byla nastavena default hodnota pro agenty co nezvladaji PhantomJS --->
#   <title ng:bind-template="{{metaSeo.title}}">
#    Sreality.cz â¢ reality a nemovitosti z celÃ© ÄR
#   </title>
#   <meta content="NejvÄtÅ¡Ã­ nabÃ­dka nemovitostÃ­ v ÄR. NabÃ­zÃ­me byty, domy, novostavby, nebytovÃ© prostory, pozemky a dalÅ¡Ã­ reality k prodeji i pronÃ¡jmu. Sreality.cz" name="description"/>
#   <meta content="Sreality.cz â¢ reality a nemovitosti z celÃ© ÄR" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.sreality.cz/img/sreality-logo-og.png" property="og:image"/>
# ...

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
soup.get_text
# Out:
# <bound method Tag.get_text of <!DOCTYPE doctype html>
#
# <html lang="{{ html.lang }}" ng-app="sreality" ng-controller="MainCtrl">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/>
# <!--- Nastaveni meta pres JS a ne pres Angular, aby byla nastavena default hodnota pro agenty co nezvladaji PhantomJS --->
# <title ng:bind-template="{{metaSeo.title}}">Sreality.cz â¢ reality a nemovitosti z celÃ© ÄR</title>
# <meta content="NejvÄtÅ¡Ã­ nabÃ­dka nemovitostÃ­ v ÄR. NabÃ­zÃ­me byty, domy, novostavby, nebytovÃ© prostory, pozemky a dalÅ¡Ã­ reality k prodeji i pronÃ¡jmu. Sreality.cz" name="description"/>
# <meta content="Sreality.cz â¢ reality a nemovitosti z celÃ© ÄR" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.sreality.cz/img/sreality-logo-og.png" property="og:image"/>
# ...

# %%
page_1 = requests.get("https://www.sreality.cz/detail/pronajem/byt/4+kk/praha-nove-mesto-na-morani/2573352540#img=0&fullscreen=false")

# %%
soup_1 = BeautifulSoup(page_1.text, "html.parser")

# %%
soup_1.get_text()
# Out:
# '\n\n\n\n\n\n\nSreality.cz â\x80¢ reality a nemovitosti z celÃ© Ä\x8cR\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\twindow.__insp = window.__insp || [];\n\t__insp.push([\'wid\', 821249485]);\n\t__insp.push(["virtualPage"]);\n\t(function() {\n\tfunction ldinsp(){if(typeof window.__inspld != "undefined") return; window.__inspld = 1; var insp = document.createElement(\'script\'); insp.type = \'text/javascript\'; insp.async = true; insp.id = "inspsync"; insp.src = (\'https:\' == document.location.protocol ? \'https\' : \'http\') + \'://cdn.inspectlet.com/inspectlet.js\'; var x = document.getElementsByTagName(\'script\')[0]; x.parentNode.insertBefore(insp, x); };\n\tsetTimeout(ldinsp, 500); document.readyState != "complete" ? (window.attachEvent ? window.attachEvent(\'onload\', ldinsp) : window.addEventListener(\'load\', ldinsp, false)) : ldinsp();\n\t})();\n\t\n\n\n(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\': new Date().getTime(),event:\'gtm.js\'});var
# ...

# %%
print(soup2.prettify())
# Out:
# <html class="ng-scope" lang="cs" ng-app="sreality" ng-controller="MainCtrl">
#  <head>
#   <style type="text/css">
#    @charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\:form{display:block;}.ng-animate-block-transitions{transition:0s all!important;-webkit-transition:0s all!important;}.ng-hide-add-active,.ng-hide-remove{display:block!important;}
#   </style>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/>
#   <!--- Nastaveni meta pres JS a ne pres Angular, aby byla nastavena default hodnota pro agenty co nezvladaji PhantomJS --->
#   <title class="ng-binding" ng:bind-template="Byty k pronájmu Praha • Sreality.cz">
#    Byty k pronájmu Praha • Sreality.cz
#   </title>
# ...

# %%
links = driver.find_elements_by_xpath("//a[@href]")
for link in links:
    print(link.get_attribute("href"))
# Out:
# https://play.google.com/store/apps/details?id=cz.seznam.sreality
# https://www.sreality.cz/
# https://www.sreality.cz/en/search/to-rent/apartments/praha
# https://www.sreality.cz/ru/search/to-rent/apartments/praha
# https://www.seznam.cz/
# https://www.sreality.cz/en/search/to-rent/apartments/praha
# https://www.sreality.cz/ru/search/to-rent/apartments/praha
# https://vyzkumnik.seznam.cz/
# https://napoveda.seznam.cz/cz/sreality/pravidla-sreality/vseobecne-obchodni-podminky/vop-pro-vkladani-jednorazove-inzerce-do-databaze-sreality/#spotrebitel
# https://www.seznam.cz/ochranaudaju
# https://napoveda.seznam.cz/cz/sreality/pravidla-sreality/vseobecne-obchodni-podminky/
# https://www.seznam.cz/reklama/cz/obsahovy-web/sluzba-sreality
# https://www.sreality.cz/realitni-software
# http://sreality.seznamblog.cz/
# https://napoveda.seznam.cz/cz/sreality/
# mailto:info@sreality.cz?subject=Dotaz%20ze%20sluzby%20sreality.cz
# https://napoveda.seznam.cz/cz/sreality/kontakty-sreality-cz/
# ...

# %%
lin_suf = links[1]['href']
lin_pref = "https://www.sreality.cz"
lin = lin_pref + lin_suf
lin
# Out:
# 'https://www.sreality.cz/detail/pronajem/byt/3+kk/praha-vinohrady-namesti-jiriho-z-podebrad/1410481756'

# %%
driver = webdriver.Chrome("C:\\chromedriver\\chromedriver.exe")
driver.get(lin)
reso = driver.execute_script("return document.documentElement.outerHTML")

# %%
soupu = BeautifulSoup(reso, "lxml")

# %%
print(soupu.prettify())
# Out:
# <html class="ng-scope" lang="cs" ng-app="sreality" ng-controller="MainCtrl">
#  <head>
#   <style type="text/css">
#    @charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\:form{display:block;}.ng-animate-block-transitions{transition:0s all!important;-webkit-transition:0s all!important;}.ng-hide-add-active,.ng-hide-remove{display:block!important;}
#   </style>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/>
#   <!--- Nastaveni meta pres JS a ne pres Angular, aby byla nastavena default hodnota pro agenty co nezvladaji PhantomJS --->
#   <title class="ng-binding" ng:bind-template="Pronájem bytu 3+kk 95 m², náměstí Jiřího z Poděbrad, Praha - Vinohrady • Sreality.cz">
#    Pronájem bytu 3+kk 95 m², náměstí Jiřího z Poděbrad, Praha - Vinohrady • Sreality.cz
#   </title>
# ...

# %%
ex = soupu.find_all('ul')[1].get_text()
ex.replace("\n", "")
# Out:
# 'Podlaží:3. podlažíUžitná plocha:95m2Parkování:1Energetická náročnost budovy:Třída G - Mimořádně nehospodárnáVybavení:ČástečněVýtah:'

# %%
ex = soupu.get_text()
b = ex.replace("\n", "")
b.replace("\t", "")
# Out:
# '@charset "UTF-8";[ng\\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\\:form{display:block;}.ng-animate-block-transitions{transition:0s all!important;-webkit-transition:0s all!important;}.ng-hide-add-active,.ng-hide-remove{display:block!important;}Pronájem bytu 3+kk 95\xa0m², náměstí Jiřího z Poděbrad, Praha - Vinohrady • Sreality.czwindow.__insp = window.__insp || [];__insp.push([\'wid\', 821249485]);__insp.push(["virtualPage"]);(function() {function ldinsp(){if(typeof window.__inspld != "undefined") return; window.__inspld = 1; var insp = document.createElement(\'script\'); insp.type = \'text/javascript\'; insp.async = true; insp.id = "inspsync"; insp.src = (\'https:\' == document.location.protocol ? \'https\' : \'http\') + \'://cdn.inspectlet.com/inspectlet.js\'; var x = document.getElementsByTagName(\'script\')[0]; x.parentNode.insertBefore(insp, x); };setTimeout(ldinsp, 500); document.readyState != "complete" ? (window.
# ...

# %% [markdown]
# # Start of a nice jupyter

# %%
import time

# %%
from selenium import webdriver

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# # How is the link structured

# %% [markdown]
# The website is located under domain name www.sreality.cz
#
# Then it allows a client to search real estate under specified parameters.
# We specify:
# renting
# type: flats
# location: Prague
#
# Then it displays 20 adverts per page

# %%
link_base = "https://www.sreality.cz/"

# %%
search = "hledani/pronajem/byty/praha"

# %%
pg = "?strana="

# %%
matches = 7448

# %%
pages = ceil(matches/20)

# %%
pages
# Out:
# 373

# %%
all_pages = [link_base+search+pg+str(k+1) for k in range(0, pages)]

# %%
all_pages[::372]
# Out:
# ['https://www.sreality.cz/hledani/pronajem/byty/praha?strana=1',
#  'https://www.sreality.cz/hledani/pronajem/byty/praha?strana=373']

# %% [markdown]
# Now we gathered all the links to give us the link that we will later scrape.
# Sreality is a dynamic page so we will use selenium <3

# %% [markdown]
# ## Selenium

# %% [markdown]
# code for one page

# %%
driver = webdriver.Chrome("C:\\chromedriver\\chromedriver.exe")
driver.get("https://www.sreality.cz/hledani/pronajem/byty/praha")
res = driver.execute_script("return document.documentElement.outerHTML")

# %%
soup = BeautifulSoup(res, "lxml")

# %%
links = soup.find_all("a", {"class":"title"})

# %%
links[1]['href']
# Out:
# '/detail/pronajem/byt/3+kk/praha-vinohrady-namesti-jiriho-z-podebrad/1410481756'

# %% [markdown]
# ## for many pages

# %%
driver = webdriver.Chrome("C:\\chromedriver\\chromedriver.exe")
all_links = []
for k in range(2):
    driver.get(all_pages[k])
    time.sleep(4)
    res = driver.execute_script("return document.documentElement.outerHTML")
    soup = BeautifulSoup(res, "lxml")
    links = soup.find_all("a", {"class":"title"})
    for j in links:
        all_links.append(j['href'])

# %%
all_links
# Out:
# ['/detail/pronajem/byt/2+kk/praha-nove-mesto-u-pujcovny/1159741020',
#  '/detail/pronajem/byt/2+kk/praha-zlicin-misovicka/2322808412',
#  '/detail/pronajem/byt/3+kk/praha-michle-magistru/2537963100',
#  '/detail/pronajem/byt/1+kk/praha-holesovice-poupetova/2921610844',
#  '/detail/pronajem/byt/1+kk/praha-modrany-k-vystrkovu/2653175388',
#  '/detail/pronajem/byt/1+1/praha-hloubetin-svestkova/203701852',
#  '/detail/pronajem/byt/2+1/praha-strasnice-dvouletky/1545879132',
#  '/detail/pronajem/byt/1+kk/praha-praha-8-krizikova/3156491868',
#  '/detail/pronajem/byt/3+kk/praha-zizkov-vlkova/2619620956',
#  '/detail/pronajem/byt/1+kk/praha-vinohrady-jagellonska/4230233692',
#  '/detail/pronajem/byt/1+1/praha-vinohrady-machova/827199836',
#  '/detail/pronajem/byt/2+kk/praha-zizkov-blahnikova/2249539164',
#  '/detail/pronajem/byt/4+kk/praha-zizkov-cimburkova/2099527260',
#  '/detail/pronajem/byt/1+kk/praha-holesovice-poupetova/2367962716',
# ...

# %% [markdown]
# it turns out we want to left our the firt link because it is a sponsored link and it could create duplicates

# %% [markdown]
# I will deal with this tomorrow
